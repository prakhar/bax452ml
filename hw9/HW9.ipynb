# %% [markdown]
# ## HW9: Sentiment Analysis using AWS Comprehend and GCP Natural Language API

# %% [markdown]
# ## Importing libraries and defining functions for sentiment analysis

# %%
import argparse
import sys
import pandas as pd
from google.cloud import language
from google.cloud.language import enums
from google.cloud.language import types
import six
import boto3
import json
import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "/Users/prakhar/Downloads/My First Project-1ffdea6c6512.json"


def gcp_sentiment_analysis(text):
    """Detects sentiment in the text."""
    client = language.LanguageServiceClient()

    if isinstance(text, six.binary_type):
        text = text.decode('utf-8')

    # Instantiates a plain text document.
    # [START migration_document_text]
    # [START migration_analyze_sentiment]
    document = types.Document(
        content=text,
        type=enums.Document.Type.PLAIN_TEXT)
    # [END migration_document_text]

    # Detects sentiment in the document. You can also analyze HTML with:
    #   document.type == enums.Document.Type.HTML
    sentiment = client.analyze_sentiment(document).document_sentiment

    if(sentiment.score > 0.3):
        return "POSITIVE"
    elif(sentiment.score < -0.3):
        return "NEGATIVE"
    else:
        return "NEUTRAL"
    
def aws_sentiment_analysis(text):
    comprehend = boto3.client(service_name='comprehend', region_name='us-east-1')
    result = eval(json.dumps(comprehend.detect_sentiment(Text=text, LanguageCode='en'), sort_keys=True, indent=4))
    return result['Sentiment']
    
    #return(comprehend.detect_sentiment(Text=text, LanguageCode='en'), sort_keys=True, indent=4)

# %% [markdown]
# ## Data loading and cleaning

# %%
def parse(path):
  #g = gzip.open(path, 'r')
  g = open(path, 'rb')
  for l in g:
    yield eval(l)

def getDF(path):
  i = 0
  df = {}
  for d in parse(path):
    df[i] = d
    i += 1
  return pd.DataFrame.from_dict(df, orient='index')



df = getDF('amazonreviews') 
df = df.drop('reviewerName', 1)
df = df.drop('helpful', 1)
df = df.drop('summary', 1)
df = df.drop('unixReviewTime', 1)
df = df.drop('reviewerID', 1)
df = df.drop('asin', 1)
df = df.drop('reviewTime', 1)
df = df.drop('overall', 1)
df.head()
# Out:
#                                           reviewText
# 0  Spiritually and mentally inspiring! A book tha...
# 1  This is one my must have books. It is a master...
# 2  This book provides a reflection that you can a...
# 3  I first read THE PROPHET in college back in th...
# 4  A timeless classic.  It is a very demanding an...

# %% [markdown]
# ## Removing reviews > 5000 bytes in size as AWS has that size limit

# %%
df['size'] = df['reviewText'].apply(sys.getsizeof)
df = df[df['size'] < 5000]

# %% [markdown]
# ## GCP Sentiment Analysis

# %%
df['gcp_sentiment_analysis'] = df['reviewText'].apply(gcp_sentiment_analysis)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# ## AWS Sentiment Analysis

# %%
df['aws_sentiment_analysis'] = df['reviewText'].apply(aws_sentiment_analysis)
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
# 992  An intriguingly wonderful history lesson that ...               POSITIVE
# 993  My two best friends and I are all avid readers...               POSITIVE
# 994  This book is a must-read. I couldn't put it do...                NEUTRAL
# 995  Stop reading reviews and buy the book! Serious...                NEUTRAL
# 996  Water for Elephants is an awesome story about ...               POSITIVE
# 997  Not being, even remotely, a Robert Pattinson f...                NEUTRAL
# 998  Yes, this story reads like a script and I was ...                NEUTRAL
# 999  I loved this book, even though I have sold a l...               POSITIVE
#
#      size aws_sentiment_analysis
# 0     178               POSITIVE
# 1     317               POSITIVE
# 2     251               POSITIVE
# 3     880               POSITIVE
# 4     862               POSITIVE
# 5     343               POSITIVE
# 6     287               POSITIVE
# 7     182               POSITIVE
# 8     336               POSITIVE
# 9     309               POSITIVE
# 10    181               POSITIVE
# 11    240               POSITIVE
# 12    170               POSITIVE
# 13    955               POSITIVE
# 14    919               POSITIVE
# 15    476               POSITIVE
# 16    409               POSITIVE
# 17    534               POSITIVE
# 18   1037               POSITIVE
# 19    392               POSITIVE
# 20    286               POSITIVE
# 21    246               POSITIVE
# 22    388               POSITIVE
# 23    760               POSITIVE
# 24    166               POSITIVE
# 25    481               POSITIVE
# 26    254               POSITIVE
# 27    168               POSITIVE
# 28    171               POSITIVE
# 29    464               POSITIVE
# ..    ...                    ...
# 970   386               POSITIVE
# 971   185               POSITIVE
# 972   610               POSITIVE
# 973   560               POSITIVE
# 974   431               POSITIVE
# 975   811               POSITIVE
# 976  2652               NEGATIVE
# 977   178               POSITIVE
# 978   175               POSITIVE
# 979   638               POSITIVE
# 980   248               POSITIVE
# 981  1379               POSITIVE
# 982   191               POSITIVE
# 983   402               POSITIVE
# 984  4034               POSITIVE
# 985   618               POSITIVE
# 986   273               POSITIVE
# 987   421               POSITIVE
# 988   181               POSITIVE
# 989   474               POSITIVE
# 990  1642               POSITIVE
# 991   380                  MIXED
# 992   214               POSITIVE
# 993   576               POSITIVE
# 994   360               POSITIVE
# 995   193               POSITIVE
# 996   573               POSITIVE
# 997   559               POSITIVE
# 998   632                  MIXED
# 999   285               POSITIVE
#
# [996 rows x 4 columns]

# %% [markdown]
# ## GCP Sentiment Analysis Summary

# %%
df.groupby(['gcp_sentiment_analysis']).count()
# Out:
#                         reviewText  size  aws_sentiment_analysis
# gcp_sentiment_analysis
# NEGATIVE                        60    60                      60
# NEUTRAL                        374   374                     374
# POSITIVE                       562   562                     562

# %% [markdown]
# ## AWS Sentiment Analysis Summary

# %%
df.groupby(['aws_sentiment_analysis']).count()
# Out:
#                         reviewText  gcp_sentiment_analysis  size
# aws_sentiment_analysis
# MIXED                           53                      53    53
# NEGATIVE                        56                      56    56
# NEUTRAL                         42                      42    42
# POSITIVE                       845                     845   845
